# %%
import torch
import pandas as pd
import numpy as np
from pathlib import Path

def load_eeg_dataset(folder_path):
    """
    Load EEG data and events from a directory containing CSV files.
    Returns tensors for features and labels.

    Args:
        folder_path (str): Path to the folder containing the data and events CSV files.

    Returns:
        features_tensor (torch.Tensor): Tensor containing all EEG features.
        labels_tensor (torch.Tensor): Tensor containing all corresponding labels.
    """
    folder = Path(folder_path)
    all_features = []
    all_labels = []
    
    # Get all data files in the directory
    data_files = list(folder.glob('*_data.csv'))
    print(f"Found {len(data_files)} data files in the folder: {folder_path}")
    
    for data_file in data_files:
        # Print the current data file being processed
        print(f"\nProcessing data file: {data_file.name}")
        
        # Extract subject and series from filename
        filename_parts = data_file.stem.split('_')
        subject = filename_parts[0][4:]  # Extract from 'subjX'
        series = filename_parts[1][6:]   # Extract from 'seriesY'
        
        # Print extracted subject and series
        print(f"Extracted subject: {subject}, series: {series}")
        
        # Find corresponding events file
        events_file = folder / f"subj{subject}_series{series}_events.csv"
        print(f"Looking for events file: {events_file.name}")
        
        if not events_file.exists():
            print(f"Events file not found for {data_file.name}, skipping...")
            continue
            
        # Load data CSV (excluding timestep column)
        print(f"Loading data from {data_file.name}")
        data_df = pd.read_csv(data_file)
        features = data_df.iloc[:, 1:].values.astype(np.float32)
        print(f"Loaded data shape: {features.shape}")
        
        # Load events CSV and select relevant columns
        print(f"Loading events from {events_file.name}")
        events_df = pd.read_csv(events_file)
        labels = events_df[['HandStart', 'BothStartLoadPhase', 
                           'LiftOff', 'Replace', 'BothReleased']].values.astype(np.float32)
        print(f"Loaded labels shape: {labels.shape}")
        
        # Verify alignment
        if len(features) != len(labels):
            print(f"Mismatch in {data_file.name}: features shape {features.shape}, labels shape {labels.shape}. Skipping...")
            continue
            
        # Append features and labels to the lists
        all_features.append(features)
        all_labels.append(labels)
        print(f"Added data to batch. Current total features shape: {np.concatenate(all_features, axis=0).shape}, labels shape: {np.concatenate(all_labels, axis=0).shape}")
        print("-" * 50)  # Separator for readability

    # Check if any valid data was found
    if len(all_features) == 0 or len(all_labels) == 0:
        raise ValueError("No valid data files found in the specified folder.")

    # Combine all data
    print("\nCombining all data into tensors...")
    features_tensor = torch.tensor(np.concatenate(all_features, axis=0))
    labels_tensor = torch.tensor(np.concatenate(all_labels, axis=0))
    print(f"Final features tensor shape: {features_tensor.shape}")
    print(f"Final labels tensor shape: {labels_tensor.shape}")
    
    print("\nData loading completed successfully!")
    return features_tensor, labels_tensor
train_features, train_labels = load_eeg_dataset('grasp-and-lift-eeg-detection/train')
# Out:
# Found 96 data files in the folder: grasp-and-lift-eeg-detection/train
#
# Processing data file: subj8_series4_data.csv
# Extracted subject: 8, series: 4
# Looking for events file: subj8_series4_events.csv
# Loading data from subj8_series4_data.csv
# Loaded data shape: (242562, 32)
# Loading events from subj8_series4_events.csv
# Loaded labels shape: (242562, 5)
# Added data to batch. Current total features shape: (242562, 32), labels shape: (242562, 5)
# --------------------------------------------------
#
# Processing data file: subj8_series5_data.csv
# Extracted subject: 8, series: 5
# Looking for events file: subj8_series5_events.csv
# Loading data from subj8_series5_data.csv
# Loaded data shape: (118716, 32)
# Loading events from subj8_series5_events.csv
# Loaded labels shape: (118716, 5)
# Added data to batch. Current total features shape: (361278, 32), labels shape: (361278, 5)
# --------------------------------------------------
#
# Processing data file: subj6_series3_data.csv
# Extracted subject: 6, series: 3
# Looking for events file: subj6_series3_events.csv
# Loading data from subj6_series3_data.csv
# Loaded data shape: (221892, 32)
# Loading events from subj6_series3_events.csv
# Loaded labels shape: (221892, 5)
# Added data to batch. Current total features shape: (583170, 32), labels shape: (583170, 5)
# --------------------------------------------------
#
# Processing data file: subj5_series6_data.csv
# Extracted subject: 5, series: 6
# Looking for events file: subj5_series6_events.csv
# Loading data from subj5_series6_data.csv
# Loaded data shape: (226735, 32)
# Loading events from subj5_series6_events.csv
# Loaded labels shape: (226735, 5)
# Added data to batch. Current total features shape: (809905, 32), labels shape: (809905, 5)
# --------------------------------------------------
#
# Processing data file: subj6_series2_data.csv
# Extracted subject: 6, series: 2
# Looking for events file: subj6_series2_events.csv
# Loading data from subj6_series2_data.csv
# Loaded data shape: (267738, 32)
# Loading events from subj6_series2_events.csv
# Loaded labels shape: (267738, 5)
# Added data to batch. Current total features shape: (1077643, 32), labels shape: (1077643, 5)
# --------------------------------------------------
#
# Processing data file: subj5_series7_data.csv
# Extracted subject: 5, series: 7
# Looking for events file: subj5_series7_events.csv
# Loading data from subj5_series7_data.csv
# Loaded data shape: (135260, 32)
# Loading events from subj5_series7_events.csv
# Loaded labels shape: (135260, 5)
# Added data to batch. Current total features shape: (1212903, 32), labels shape: (1212903, 5)
# --------------------------------------------------
#
# Processing data file: subj3_series5_data.csv
# Extracted subject: 3, series: 5
# Looking for events file: subj3_series5_events.csv
# Loading data from subj3_series5_data.csv
# Loaded data shape: (248572, 32)
# Loading events from subj3_series5_events.csv
# Loaded labels shape: (248572, 5)
# Added data to batch. Current total features shape: (1461475, 32), labels shape: (1461475, 5)
# --------------------------------------------------
#
# Processing data file: subj3_series4_data.csv
# Extracted subject: 3, series: 4
# Looking for events file: subj3_series4_events.csv
# Loading data from subj3_series4_data.csv
# Loaded data shape: (196416, 32)
# Loading events from subj3_series4_events.csv
# Loaded labels shape: (196416, 5)
# Added data to batch. Current total features shape: (1657891, 32), labels shape: (1657891, 5)
# --------------------------------------------------
#
# Processing data file: subj6_series8_data.csv
# Extracted subject: 6, series: 8
# Looking for events file: subj6_series8_events.csv
# Loading data from subj6_series8_data.csv
# Loaded data shape: (135837, 32)
# Loading events from subj6_series8_events.csv
# Loaded labels shape: (135837, 5)
# Added data to batch. Current total features shape: (1793728, 32), labels shape: (1793728, 5)
# --------------------------------------------------
#
# Processing data file: subj12_series1_data.csv
# Extracted subject: 12, series: 1
# Looking for events file: subj12_series1_events.csv
# Loading data from subj12_series1_data.csv
# Loaded data shape: (151123, 32)
# Loading events from subj12_series1_events.csv
# Loaded labels shape: (151123, 5)
# Added data to batch. Current total features shape: (1944851, 32), labels shape: (1944851, 5)
# --------------------------------------------------
#
# Processing data file: subj11_series4_data.csv
# Extracted subject: 11, series: 4
# Looking for events file: subj11_series4_events.csv
# Loading data from subj11_series4_data.csv
# Loaded data shape: (141452, 32)
# Loading events from subj11_series4_events.csv
# Loaded labels shape: (141452, 5)
# Added data to batch. Current total features shape: (2086303, 32), labels shape: (2086303, 5)
# --------------------------------------------------
#
# Processing data file: subj11_series5_data.csv
# Extracted subject: 11, series: 5
# Looking for events file: subj11_series5_events.csv
# Loading data from subj11_series5_data.csv
# Loaded data shape: (250788, 32)
# Loading events from subj11_series5_events.csv
# Loaded labels shape: (250788, 5)
# Added data to batch. Current total features shape: (2337091, 32), labels shape: (2337091, 5)
# --------------------------------------------------
#
# Processing data file: subj10_series8_data.csv
# Extracted subject: 10, series: 8
# Looking for events file: subj10_series8_events.csv
# Loading data from subj10_series8_data.csv
# Loaded data shape: (126733, 32)
# Loading events from subj10_series8_events.csv
# Loaded labels shape: (126733, 5)
# Added data to batch. Current total features shape: (2463824, 32), labels shape: (2463824, 5)
# --------------------------------------------------
#
# Processing data file: subj9_series2_data.csv
# Extracted subject: 9, series: 2
# Looking for events file: subj9_series2_events.csv
# Loading data from subj9_series2_data.csv
# Loaded data shape: (209212, 32)
# Loading events from subj9_series2_events.csv
# Loaded labels shape: (209212, 5)
# Added data to batch. Current total features shape: (2673036, 32), labels shape: (2673036, 5)
# --------------------------------------------------
#
# Processing data file: subj9_series3_data.csv
# Extracted subject: 9, series: 3
# Looking for events file: subj9_series3_events.csv
# Loading data from subj9_series3_data.csv
# Loaded data shape: (252772, 32)
# Loading events from subj9_series3_events.csv
# Loaded labels shape: (252772, 5)
# Added data to batch. Current total features shape: (2925808, 32), labels shape: (2925808, 5)
# --------------------------------------------------
#
# Processing data file: subj7_series5_data.csv
# Extracted subject: 7, series: 5
# Looking for events file: subj7_series5_events.csv
# Loading data from subj7_series5_data.csv
# Loaded data shape: (212546, 32)
# Loading events from subj7_series5_events.csv
# Loaded labels shape: (212546, 5)
# Added data to batch. Current total features shape: (3138354, 32), labels shape: (3138354, 5)
# --------------------------------------------------
#
# Processing data file: subj7_series4_data.csv
# Extracted subject: 7, series: 4
# Looking for events file: subj7_series4_events.csv
# Loading data from subj7_series4_data.csv
# Loaded data shape: (263711, 32)
# Loading events from subj7_series4_events.csv
# Loaded labels shape: (263711, 5)
# Added data to batch. Current total features shape: (3402065, 32), labels shape: (3402065, 5)
# --------------------------------------------------
#
# Processing data file: subj4_series1_data.csv
# Extracted subject: 4, series: 1
# Looking for events file: subj4_series1_events.csv
# Loading data from subj4_series1_data.csv
# Loaded data shape: (246612, 32)
# Loading events from subj4_series1_events.csv
# Loaded labels shape: (246612, 5)
# Added data to batch. Current total features shape: (3648677, 32), labels shape: (3648677, 5)
# --------------------------------------------------
#
# Processing data file: subj2_series8_data.csv
# Extracted subject: 2, series: 8
# Looking for events file: subj2_series8_events.csv
# Loading data from subj2_series8_data.csv
# Loaded data shape: (149945, 32)
# Loading events from subj2_series8_events.csv
# Loaded labels shape: (149945, 5)
# Added data to batch. Current total features shape: (3798622, 32), labels shape: (3798622, 5)
# --------------------------------------------------
#
# Processing data file: subj10_series2_data.csv
# Extracted subject: 10, series: 2
# Looking for events file: subj10_series2_events.csv
# Loading data from subj10_series2_data.csv
# Loaded data shape: (216873, 32)
# Loading events from subj10_series2_events.csv
# Loaded labels shape: (216873, 5)
# Added data to batch. Current total features shape: (4015495, 32), labels shape: (4015495, 5)
# --------------------------------------------------
#
# Processing data file: subj10_series3_data.csv
# Extracted subject: 10, series: 3
# Looking for events file: subj10_series3_events.csv
# Loading data from subj10_series3_data.csv
# Loaded data shape: (142976, 32)
# Loading events from subj10_series3_events.csv
# Loaded labels shape: (142976, 5)
# Added data to batch. Current total features shape: (4158471, 32), labels shape: (4158471, 5)
# --------------------------------------------------
#
# Processing data file: subj1_series6_data.csv
# Extracted subject: 1, series: 6
# Looking for events file: subj1_series6_events.csv
# Loading data from subj1_series6_data.csv
# Loaded data shape: (249550, 32)
# Loading events from subj1_series6_events.csv
# Loaded labels shape: (249550, 5)
# Added data to batch. Current total features shape: (4408021, 32), labels shape: (4408021, 5)
# --------------------------------------------------
#
# Processing data file: subj2_series3_data.csv
# Extracted subject: 2, series: 3
# Looking for events file: subj2_series3_events.csv
# Loading data from subj2_series3_data.csv
# Loaded data shape: (152745, 32)
# Loading events from subj2_series3_events.csv
# Loaded labels shape: (152745, 5)
# Added data to batch. Current total features shape: (4560766, 32), labels shape: (4560766, 5)
# --------------------------------------------------
#
# Processing data file: subj1_series7_data.csv
# Extracted subject: 1, series: 7
# Looking for events file: subj1_series7_events.csv
# Loading data from subj1_series7_data.csv
# Loaded data shape: (119561, 32)
# Loading events from subj1_series7_events.csv
# Loaded labels shape: (119561, 5)
# Added data to batch. Current total features shape: (4680327, 32), labels shape: (4680327, 5)
# --------------------------------------------------
#
# Processing data file: subj2_series2_data.csv
# Extracted subject: 2, series: 2
# Looking for events file: subj2_series2_events.csv
# Loading data from subj2_series2_data.csv
# Loaded data shape: (330082, 32)
# Loading events from subj2_series2_events.csv
# Loaded labels shape: (330082, 5)
# Added data to batch. Current total features shape: (5010409, 32), labels shape: (5010409, 5)
# --------------------------------------------------
#
# Processing data file: subj9_series8_data.csv
# Extracted subject: 9, series: 8
# Looking for events file: subj9_series8_events.csv
# Loading data from subj9_series8_data.csv
# Loaded data shape: (127494, 32)
# Loading events from subj9_series8_events.csv
# Loaded labels shape: (127494, 5)
# Added data to batch. Current total features shape: (5137903, 32), labels shape: (5137903, 5)
# --------------------------------------------------
#
# Processing data file: subj7_series2_data.csv
# Extracted subject: 7, series: 2
# Looking for events file: subj7_series2_events.csv
# Loading data from subj7_series2_data.csv
# Loaded data shape: (212898, 32)
# Loading events from subj7_series2_events.csv
# Loaded labels shape: (212898, 5)
# Added data to batch. Current total features shape: (5350801, 32), labels shape: (5350801, 5)
# --------------------------------------------------
#
# Processing data file: subj4_series7_data.csv
# Extracted subject: 4, series: 7
# Looking for events file: subj4_series7_events.csv
# Loading data from subj4_series7_data.csv
# Loaded data shape: (121495, 32)
# Loading events from subj4_series7_events.csv
# Loaded labels shape: (121495, 5)
# Added data to batch. Current total features shape: (5472296, 32), labels shape: (5472296, 5)
# --------------------------------------------------
#
# Processing data file: subj7_series3_data.csv
# Extracted subject: 7, series: 3
# Looking for events file: subj7_series3_events.csv
# Loading data from subj7_series3_data.csv
# Loaded data shape: (223684, 32)
# Loading events from subj7_series3_events.csv
# Loaded labels shape: (223684, 5)
# Added data to batch. Current total features shape: (5695980, 32), labels shape: (5695980, 5)
# --------------------------------------------------
#
# Processing data file: subj4_series6_data.csv
# Extracted subject: 4, series: 6
# Looking for events file: subj4_series6_events.csv
# Loading data from subj4_series6_data.csv
# Loaded data shape: (243659, 32)
# Loading events from subj4_series6_events.csv
# Loaded labels shape: (243659, 5)
# Added data to batch. Current total features shape: (5939639, 32), labels shape: (5939639, 5)
# --------------------------------------------------
#
# Processing data file: subj9_series5_data.csv
# Extracted subject: 9, series: 5
# Looking for events file: subj9_series5_events.csv
# Loading data from subj9_series5_data.csv
# Loaded data shape: (248301, 32)
# Loading events from subj9_series5_events.csv
# Loaded labels shape: (248301, 5)
# Added data to batch. Current total features shape: (6187940, 32), labels shape: (6187940, 5)
# --------------------------------------------------
#
# Processing data file: subj9_series4_data.csv
# Extracted subject: 9, series: 4
# Looking for events file: subj9_series4_events.csv
# Loading data from subj9_series4_data.csv
# Loaded data shape: (208470, 32)
# Loading events from subj9_series4_events.csv
# Loaded labels shape: (208470, 5)
# Added data to batch. Current total features shape: (6396410, 32), labels shape: (6396410, 5)
# --------------------------------------------------
#
# Processing data file: subj10_series5_data.csv
# Extracted subject: 10, series: 5
# Looking for events file: subj10_series5_events.csv
# Loading data from subj10_series5_data.csv
# Loaded data shape: (136568, 32)
# Loading events from subj10_series5_events.csv
# Loaded labels shape: (136568, 5)
# Added data to batch. Current total features shape: (6532978, 32), labels shape: (6532978, 5)
# --------------------------------------------------
#
# Processing data file: subj10_series4_data.csv
# Extracted subject: 10, series: 4
# Looking for events file: subj10_series4_events.csv
# Loading data from subj10_series4_data.csv
# Loaded data shape: (211225, 32)
# Loading events from subj10_series4_events.csv
# Loaded labels shape: (211225, 5)
# Added data to batch. Current total features shape: (6744203, 32), labels shape: (6744203, 5)
# --------------------------------------------------
#
# Processing data file: subj7_series8_data.csv
# Extracted subject: 7, series: 8
# Looking for events file: subj7_series8_events.csv
# Loading data from subj7_series8_data.csv
# Loaded data shape: (140424, 32)
# Loading events from subj7_series8_events.csv
# Loaded labels shape: (140424, 5)
# Added data to batch. Current total features shape: (6884627, 32), labels shape: (6884627, 5)
# --------------------------------------------------
#
# Processing data file: subj1_series1_data.csv
# Extracted subject: 1, series: 1
# Looking for events file: subj1_series1_events.csv
# Loading data from subj1_series1_data.csv
# Loaded data shape: (119496, 32)
# Loading events from subj1_series1_events.csv
# Loaded labels shape: (119496, 5)
# Added data to batch. Current total features shape: (7004123, 32), labels shape: (7004123, 5)
# --------------------------------------------------
#
# Processing data file: subj2_series4_data.csv
# Extracted subject: 2, series: 4
# Looking for events file: subj2_series4_events.csv
# Loading data from subj2_series4_data.csv
# Loaded data shape: (278114, 32)
# Loading events from subj2_series4_events.csv
# Loaded labels shape: (278114, 5)
# Added data to batch. Current total features shape: (7282237, 32), labels shape: (7282237, 5)
# --------------------------------------------------
#
# Processing data file: subj2_series5_data.csv
# Extracted subject: 2, series: 5
# Looking for events file: subj2_series5_events.csv
# Loading data from subj2_series5_data.csv
# Loaded data shape: (151647, 32)
# Loading events from subj2_series5_events.csv
# Loaded labels shape: (151647, 5)
# Added data to batch. Current total features shape: (7433884, 32), labels shape: (7433884, 5)
# --------------------------------------------------
#
# Processing data file: subj3_series8_data.csv
# Extracted subject: 3, series: 8
# Looking for events file: subj3_series8_events.csv
# Loading data from subj3_series8_data.csv
# Loaded data shape: (114946, 32)
# Loading events from subj3_series8_events.csv
# Loaded labels shape: (114946, 5)
# Added data to batch. Current total features shape: (7548830, 32), labels shape: (7548830, 5)
# --------------------------------------------------
#
# Processing data file: subj6_series4_data.csv
# Extracted subject: 6, series: 4
# Looking for events file: subj6_series4_events.csv
# Loading data from subj6_series4_data.csv
# Loaded data shape: (137731, 32)
# Loading events from subj6_series4_events.csv
# Loaded labels shape: (137731, 5)
# Added data to batch. Current total features shape: (7686561, 32), labels shape: (7686561, 5)
# --------------------------------------------------
#
# Processing data file: subj5_series1_data.csv
# Extracted subject: 5, series: 1
# Looking for events file: subj5_series1_events.csv
# Loading data from subj5_series1_data.csv
# Loaded data shape: (227967, 32)
# Loading events from subj5_series1_events.csv
# Loaded labels shape: (227967, 5)
# Added data to batch. Current total features shape: (7914528, 32), labels shape: (7914528, 5)
# --------------------------------------------------
#
# Processing data file: subj6_series5_data.csv
# Extracted subject: 6, series: 5
# Looking for events file: subj6_series5_events.csv
# Loading data from subj6_series5_data.csv
# Loaded data shape: (215765, 32)
# Loading events from subj6_series5_events.csv
# Loaded labels shape: (215765, 5)
# Added data to batch. Current total features shape: (8130293, 32), labels shape: (8130293, 5)
# --------------------------------------------------
#
# Processing data file: subj8_series3_data.csv
# Extracted subject: 8, series: 3
# Looking for events file: subj8_series3_events.csv
# Loading data from subj8_series3_data.csv
# Loaded data shape: (123701, 32)
# Loading events from subj8_series3_events.csv
# Loaded labels shape: (123701, 5)
# Added data to batch. Current total features shape: (8253994, 32), labels shape: (8253994, 5)
# --------------------------------------------------
#
# Processing data file: subj8_series2_data.csv
# Extracted subject: 8, series: 2
# Looking for events file: subj8_series2_events.csv
# Loading data from subj8_series2_data.csv
# Loaded data shape: (239180, 32)
# Loading events from subj8_series2_events.csv
# Loaded labels shape: (239180, 5)
# Added data to batch. Current total features shape: (8493174, 32), labels shape: (8493174, 5)
# --------------------------------------------------
#
# Processing data file: subj11_series8_data.csv
# Extracted subject: 11, series: 8
# Looking for events file: subj11_series8_events.csv
# Loading data from subj11_series8_data.csv
# Loaded data shape: (134289, 32)
# Loading events from subj11_series8_events.csv
# Loaded labels shape: (134289, 5)
# Added data to batch. Current total features shape: (8627463, 32), labels shape: (8627463, 5)
# --------------------------------------------------
#
# Processing data file: subj8_series8_data.csv
# Extracted subject: 8, series: 8
# Looking for events file: subj8_series8_events.csv
# Loading data from subj8_series8_data.csv
# Loaded data shape: (124095, 32)
# Loading events from subj8_series8_events.csv
# Loaded labels shape: (124095, 5)
# Added data to batch. Current total features shape: (8751558, 32), labels shape: (8751558, 5)
# --------------------------------------------------
#
# Processing data file: subj3_series2_data.csv
# Extracted subject: 3, series: 2
# Looking for events file: subj3_series2_events.csv
# Loading data from subj3_series2_data.csv
# Loaded data shape: (192860, 32)
# Loading events from subj3_series2_events.csv
# Loaded labels shape: (192860, 5)
# Added data to batch. Current total features shape: (8944418, 32), labels shape: (8944418, 5)
# --------------------------------------------------
#
# Processing data file: subj3_series3_data.csv
# Extracted subject: 3, series: 3
# Looking for events file: subj3_series3_events.csv
# Loading data from subj3_series3_data.csv
# Loaded data shape: (229357, 32)
# Loading events from subj3_series3_events.csv
# Loaded labels shape: (229357, 5)
# Added data to batch. Current total features shape: (9173775, 32), labels shape: (9173775, 5)
# --------------------------------------------------
#
# Processing data file: subj12_series6_data.csv
# Extracted subject: 12, series: 6
# Looking for events file: subj12_series6_events.csv
# Loading data from subj12_series6_data.csv
# Loaded data shape: (266571, 32)
# Loading events from subj12_series6_events.csv
# Loaded labels shape: (266571, 5)
# Added data to batch. Current total features shape: (9440346, 32), labels shape: (9440346, 5)
# --------------------------------------------------
#
# Processing data file: subj11_series3_data.csv
# Extracted subject: 11, series: 3
# Looking for events file: subj11_series3_events.csv
# Loading data from subj11_series3_data.csv
# Loaded data shape: (266245, 32)
# Loading events from subj11_series3_events.csv
# Loaded labels shape: (266245, 5)
# Added data to batch. Current total features shape: (9706591, 32), labels shape: (9706591, 5)
# --------------------------------------------------
#
# Processing data file: subj12_series7_data.csv
# Extracted subject: 12, series: 7
# Looking for events file: subj12_series7_events.csv
# Loading data from subj12_series7_data.csv
# Loaded data shape: (147835, 32)
# Loading events from subj12_series7_events.csv
# Loaded labels shape: (147835, 5)
# Added data to batch. Current total features shape: (9854426, 32), labels shape: (9854426, 5)
# --------------------------------------------------
#
# Processing data file: subj11_series2_data.csv
# Extracted subject: 11, series: 2
# Looking for events file: subj11_series2_events.csv
# Loading data from subj11_series2_data.csv
# Loaded data shape: (147697, 32)
# Loading events from subj11_series2_events.csv
# Loaded labels shape: (147697, 5)
# Added data to batch. Current total features shape: (10002123, 32), labels shape: (10002123, 5)
# --------------------------------------------------
#
# Processing data file: subj10_series1_data.csv
# Extracted subject: 10, series: 1
# Looking for events file: subj10_series1_events.csv
# Loading data from subj10_series1_data.csv
# Loaded data shape: (262387, 32)
# Loading events from subj10_series1_events.csv
# Loaded labels shape: (262387, 5)
# Added data to batch. Current total features shape: (10264510, 32), labels shape: (10264510, 5)
# --------------------------------------------------
#
# Processing data file: subj4_series8_data.csv
# Extracted subject: 4, series: 8
# Looking for events file: subj4_series8_events.csv
# Loading data from subj4_series8_data.csv
# Loaded data shape: (121920, 32)
# Loading events from subj4_series8_events.csv
# Loaded labels shape: (121920, 5)
# Added data to batch. Current total features shape: (10386430, 32), labels shape: (10386430, 5)
# --------------------------------------------------
#
# Processing data file: subj1_series5_data.csv
# Extracted subject: 1, series: 5
# Looking for events file: subj1_series5_events.csv
# Loading data from subj1_series5_data.csv
# Loaded data shape: (210644, 32)
# Loading events from subj1_series5_events.csv
# Loaded labels shape: (210644, 5)
# Added data to batch. Current total features shape: (10597074, 32), labels shape: (10597074, 5)
# --------------------------------------------------
#
# Processing data file: subj2_series1_data.csv
# Extracted subject: 2, series: 1
# Looking for events file: subj2_series1_events.csv
# Loading data from subj2_series1_data.csv
# Loaded data shape: (291874, 32)
# Loading events from subj2_series1_events.csv
# Loaded labels shape: (291874, 5)
# Added data to batch. Current total features shape: (10888948, 32), labels shape: (10888948, 5)
# --------------------------------------------------
#
# Processing data file: subj1_series4_data.csv
# Extracted subject: 1, series: 4
# Looking for events file: subj1_series4_events.csv
# Loading data from subj1_series4_data.csv
# Loaded data shape: (116240, 32)
# Loading events from subj1_series4_events.csv
# Loaded labels shape: (116240, 5)
# Added data to batch. Current total features shape: (11005188, 32), labels shape: (11005188, 5)
# --------------------------------------------------
#
# Processing data file: subj9_series1_data.csv
# Extracted subject: 9, series: 1
# Looking for events file: subj9_series1_events.csv
# Loading data from subj9_series1_data.csv
# Loaded data shape: (141426, 32)
# Loading events from subj9_series1_events.csv
# Loaded labels shape: (141426, 5)
# Added data to batch. Current total features shape: (11146614, 32), labels shape: (11146614, 5)
# --------------------------------------------------
#
# Processing data file: subj4_series3_data.csv
# Extracted subject: 4, series: 3
# Looking for events file: subj4_series3_events.csv
# Loading data from subj4_series3_data.csv
# Loaded data shape: (131495, 32)
# Loading events from subj4_series3_events.csv
# Loaded labels shape: (131495, 5)
# Added data to batch. Current total features shape: (11278109, 32), labels shape: (11278109, 5)
# --------------------------------------------------
#
# Processing data file: subj7_series6_data.csv
# Extracted subject: 7, series: 6
# Looking for events file: subj7_series6_events.csv
# Loading data from subj7_series6_data.csv
# Loaded data shape: (147148, 32)
# Loading events from subj7_series6_events.csv
# Loaded labels shape: (147148, 5)
# Added data to batch. Current total features shape: (11425257, 32), labels shape: (11425257, 5)
# --------------------------------------------------
#
# Processing data file: subj4_series2_data.csv
# Extracted subject: 4, series: 2
# Looking for events file: subj4_series2_events.csv
# Loading data from subj4_series2_data.csv
# Loaded data shape: (208724, 32)
# Loading events from subj4_series2_events.csv
# Loaded labels shape: (208724, 5)
# Added data to batch. Current total features shape: (11633981, 32), labels shape: (11633981, 5)
# --------------------------------------------------
#
# Processing data file: subj7_series7_data.csv
# Extracted subject: 7, series: 7
# Looking for events file: subj7_series7_events.csv
# Loading data from subj7_series7_data.csv
# Loaded data shape: (144897, 32)
# Loading events from subj7_series7_events.csv
# Loaded labels shape: (144897, 5)
# Added data to batch. Current total features shape: (11778878, 32), labels shape: (11778878, 5)
# --------------------------------------------------
#
# Processing data file: subj3_series6_data.csv
# Extracted subject: 3, series: 6
# Looking for events file: subj3_series6_events.csv
# Loading data from subj3_series6_data.csv
# Loaded data shape: (116333, 32)
# Loading events from subj3_series6_events.csv
# Loaded labels shape: (116333, 5)
# Added data to batch. Current total features shape: (11895211, 32), labels shape: (11895211, 5)
# --------------------------------------------------
#
# Processing data file: subj3_series7_data.csv
# Extracted subject: 3, series: 7
# Looking for events file: subj3_series7_events.csv
# Loading data from subj3_series7_data.csv
# Loaded data shape: (115079, 32)
# Loading events from subj3_series7_events.csv
# Loaded labels shape: (115079, 5)
# Added data to batch. Current total features shape: (12010290, 32), labels shape: (12010290, 5)
# --------------------------------------------------
#
# Processing data file: subj11_series7_data.csv
# Extracted subject: 11, series: 7
# Looking for events file: subj11_series7_events.csv
# Loading data from subj11_series7_data.csv
# Loaded data shape: (141183, 32)
# Loading events from subj11_series7_events.csv
# Loaded labels shape: (141183, 5)
# Added data to batch. Current total features shape: (12151473, 32), labels shape: (12151473, 5)
# --------------------------------------------------
#
# Processing data file: subj12_series2_data.csv
# Extracted subject: 12, series: 2
# Looking for events file: subj12_series2_events.csv
# Loading data from subj12_series2_data.csv
# Loaded data shape: (270047, 32)
# Loading events from subj12_series2_events.csv
# Loaded labels shape: (270047, 5)
# Added data to batch. Current total features shape: (12421520, 32), labels shape: (12421520, 5)
# --------------------------------------------------
#
# Processing data file: subj11_series6_data.csv
# Extracted subject: 11, series: 6
# Looking for events file: subj11_series6_events.csv
# Loading data from subj11_series6_data.csv
# Loaded data shape: (215983, 32)
# Loading events from subj11_series6_events.csv
# Loaded labels shape: (215983, 5)
# Added data to batch. Current total features shape: (12637503, 32), labels shape: (12637503, 5)
# --------------------------------------------------
#
# Processing data file: subj12_series3_data.csv
# Extracted subject: 12, series: 3
# Looking for events file: subj12_series3_events.csv
# Loading data from subj12_series3_data.csv
# Loaded data shape: (230872, 32)
# Loading events from subj12_series3_events.csv
# Loaded labels shape: (230872, 5)
# Added data to batch. Current total features shape: (12868375, 32), labels shape: (12868375, 5)
# --------------------------------------------------
#
# Processing data file: subj8_series7_data.csv
# Extracted subject: 8, series: 7
# Looking for events file: subj8_series7_events.csv
# Loading data from subj8_series7_data.csv
# Loaded data shape: (118614, 32)
# Loading events from subj8_series7_events.csv
# Loaded labels shape: (118614, 5)
# Added data to batch. Current total features shape: (12986989, 32), labels shape: (12986989, 5)
# --------------------------------------------------
#
# Processing data file: subj8_series6_data.csv
# Extracted subject: 8, series: 6
# Looking for events file: subj8_series6_events.csv
# Loading data from subj8_series6_data.csv
# Loaded data shape: (191769, 32)
# Loading events from subj8_series6_events.csv
# Loaded labels shape: (191769, 5)
# Added data to batch. Current total features shape: (13178758, 32), labels shape: (13178758, 5)
# --------------------------------------------------
#
# Processing data file: subj5_series5_data.csv
# Extracted subject: 5, series: 5
# Looking for events file: subj5_series5_events.csv
# Loading data from subj5_series5_data.csv
# Loaded data shape: (265586, 32)
# Loading events from subj5_series5_events.csv
# Loaded labels shape: (265586, 5)
# Added data to batch. Current total features shape: (13444344, 32), labels shape: (13444344, 5)
# --------------------------------------------------
#
# Processing data file: subj5_series4_data.csv
# Extracted subject: 5, series: 4
# Looking for events file: subj5_series4_events.csv
# Loading data from subj5_series4_data.csv
# Loaded data shape: (136440, 32)
# Loading events from subj5_series4_events.csv
# Loaded labels shape: (136440, 5)
# Added data to batch. Current total features shape: (13580784, 32), labels shape: (13580784, 5)
# --------------------------------------------------
#
# Processing data file: subj6_series1_data.csv
# Extracted subject: 6, series: 1
# Looking for events file: subj6_series1_events.csv
# Loading data from subj6_series1_data.csv
# Loaded data shape: (149580, 32)
# Loading events from subj6_series1_events.csv
# Loaded labels shape: (149580, 5)
# Added data to batch. Current total features shape: (13730364, 32), labels shape: (13730364, 5)
# --------------------------------------------------
#
# Processing data file: subj12_series8_data.csv
# Extracted subject: 12, series: 8
# Looking for events file: subj12_series8_events.csv
# Loading data from subj12_series8_data.csv
# Loaded data shape: (154678, 32)
# Loading events from subj12_series8_events.csv
# Loaded labels shape: (154678, 5)
# Added data to batch. Current total features shape: (13885042, 32), labels shape: (13885042, 5)
# --------------------------------------------------
#
# Processing data file: subj3_series1_data.csv
# Extracted subject: 3, series: 1
# Looking for events file: subj3_series1_events.csv
# Loading data from subj3_series1_data.csv
# Loaded data shape: (122262, 32)
# Loading events from subj3_series1_events.csv
# Loaded labels shape: (122262, 5)
# Added data to batch. Current total features shape: (14007304, 32), labels shape: (14007304, 5)
# --------------------------------------------------
#
# Processing data file: subj5_series8_data.csv
# Extracted subject: 5, series: 8
# Looking for events file: subj5_series8_events.csv
# Loading data from subj5_series8_data.csv
# Loaded data shape: (129504, 32)
# Loading events from subj5_series8_events.csv
# Loaded labels shape: (129504, 5)
# Added data to batch. Current total features shape: (14136808, 32), labels shape: (14136808, 5)
# --------------------------------------------------
#
# Processing data file: subj12_series5_data.csv
# Extracted subject: 12, series: 5
# Looking for events file: subj12_series5_events.csv
# Loading data from subj12_series5_data.csv
# Loaded data shape: (230568, 32)
# Loading events from subj12_series5_events.csv
# Loaded labels shape: (230568, 5)
# Added data to batch. Current total features shape: (14367376, 32), labels shape: (14367376, 5)
# --------------------------------------------------
#
# Processing data file: subj11_series1_data.csv
# Extracted subject: 11, series: 1
# Looking for events file: subj11_series1_events.csv
# Loading data from subj11_series1_data.csv
# Loaded data shape: (223400, 32)
# Loading events from subj11_series1_events.csv
# Loaded labels shape: (223400, 5)
# Added data to batch. Current total features shape: (14590776, 32), labels shape: (14590776, 5)
# --------------------------------------------------
#
# Processing data file: subj12_series4_data.csv
# Extracted subject: 12, series: 4
# Looking for events file: subj12_series4_events.csv
# Loading data from subj12_series4_data.csv
# Loaded data shape: (156229, 32)
# Loading events from subj12_series4_events.csv
# Loaded labels shape: (156229, 5)
# Added data to batch. Current total features shape: (14747005, 32), labels shape: (14747005, 5)
# --------------------------------------------------
#
# Processing data file: subj5_series2_data.csv
# Extracted subject: 5, series: 2
# Looking for events file: subj5_series2_events.csv
# Loading data from subj5_series2_data.csv
# Loaded data shape: (138058, 32)
# Loading events from subj5_series2_events.csv
# Loaded labels shape: (138058, 5)
# Added data to batch. Current total features shape: (14885063, 32), labels shape: (14885063, 5)
# --------------------------------------------------
#
# Processing data file: subj6_series7_data.csv
# Extracted subject: 6, series: 7
# Looking for events file: subj6_series7_events.csv
# Loading data from subj6_series7_data.csv
# Loaded data shape: (133391, 32)
# Loading events from subj6_series7_events.csv
# Loaded labels shape: (133391, 5)
# Added data to batch. Current total features shape: (15018454, 32), labels shape: (15018454, 5)
# --------------------------------------------------
#
# Processing data file: subj5_series3_data.csv
# Extracted subject: 5, series: 3
# Looking for events file: subj5_series3_events.csv
# Loading data from subj5_series3_data.csv
# Loaded data shape: (259176, 32)
# Loading events from subj5_series3_events.csv
# Loaded labels shape: (259176, 5)
# Added data to batch. Current total features shape: (15277630, 32), labels shape: (15277630, 5)
# --------------------------------------------------
#
# Processing data file: subj6_series6_data.csv
# Extracted subject: 6, series: 6
# Looking for events file: subj6_series6_events.csv
# Loading data from subj6_series6_data.csv
# Loaded data shape: (257483, 32)
# Loading events from subj6_series6_events.csv
# Loaded labels shape: (257483, 5)
# Added data to batch. Current total features shape: (15535113, 32), labels shape: (15535113, 5)
# --------------------------------------------------
#
# Processing data file: subj8_series1_data.csv
# Extracted subject: 8, series: 1
# Looking for events file: subj8_series1_events.csv
# Loading data from subj8_series1_data.csv
# Loaded data shape: (200430, 32)
# Loading events from subj8_series1_events.csv
# Loaded labels shape: (200430, 5)
# Added data to batch. Current total features shape: (15735543, 32), labels shape: (15735543, 5)
# --------------------------------------------------
#
# Processing data file: subj10_series6_data.csv
# Extracted subject: 10, series: 6
# Looking for events file: subj10_series6_events.csv
# Loading data from subj10_series6_data.csv
# Loaded data shape: (257334, 32)
# Loading events from subj10_series6_events.csv
# Loaded labels shape: (257334, 5)
# Added data to batch. Current total features shape: (15992877, 32), labels shape: (15992877, 5)
# --------------------------------------------------
#
# Processing data file: subj10_series7_data.csv
# Extracted subject: 10, series: 7
# Looking for events file: subj10_series7_events.csv
# Loading data from subj10_series7_data.csv
# Loaded data shape: (132819, 32)
# Loading events from subj10_series7_events.csv
# Loaded labels shape: (132819, 5)
# Added data to batch. Current total features shape: (16125696, 32), labels shape: (16125696, 5)
# --------------------------------------------------
#
# Processing data file: subj2_series7_data.csv
# Extracted subject: 2, series: 7
# Looking for events file: subj2_series7_events.csv
# Loading data from subj2_series7_data.csv
# Loaded data shape: (150865, 32)
# Loading events from subj2_series7_events.csv
# Loaded labels shape: (150865, 5)
# Added data to batch. Current total features shape: (16276561, 32), labels shape: (16276561, 5)
# --------------------------------------------------
#
# Processing data file: subj1_series2_data.csv
# Extracted subject: 1, series: 2
# Looking for events file: subj1_series2_events.csv
# Loading data from subj1_series2_data.csv
# Loaded data shape: (271954, 32)
# Loading events from subj1_series2_events.csv
# Loaded labels shape: (271954, 5)
# Added data to batch. Current total features shape: (16548515, 32), labels shape: (16548515, 5)
# --------------------------------------------------
#
# Processing data file: subj2_series6_data.csv
# Extracted subject: 2, series: 6
# Looking for events file: subj2_series6_events.csv
# Loading data from subj2_series6_data.csv
# Loaded data shape: (206222, 32)
# Loading events from subj2_series6_events.csv
# Loaded labels shape: (206222, 5)
# Added data to batch. Current total features shape: (16754737, 32), labels shape: (16754737, 5)
# --------------------------------------------------
#
# Processing data file: subj1_series3_data.csv
# Extracted subject: 1, series: 3
# Looking for events file: subj1_series3_events.csv
# Loading data from subj1_series3_data.csv
# Loaded data shape: (217614, 32)
# Loading events from subj1_series3_events.csv
# Loaded labels shape: (217614, 5)
# Added data to batch. Current total features shape: (16972351, 32), labels shape: (16972351, 5)
# --------------------------------------------------
#
# Processing data file: subj4_series4_data.csv
# Extracted subject: 4, series: 4
# Looking for events file: subj4_series4_events.csv
# Loading data from subj4_series4_data.csv
# Loaded data shape: (205592, 32)
# Loading events from subj4_series4_events.csv
# Loaded labels shape: (205592, 5)
# Added data to batch. Current total features shape: (17177943, 32), labels shape: (17177943, 5)
# --------------------------------------------------
#
# Processing data file: subj7_series1_data.csv
# Extracted subject: 7, series: 1
# Looking for events file: subj7_series1_events.csv
# Loading data from subj7_series1_data.csv
# Loaded data shape: (307632, 32)
# Loading events from subj7_series1_events.csv
# Loaded labels shape: (307632, 5)
# Added data to batch. Current total features shape: (17485575, 32), labels shape: (17485575, 5)
# --------------------------------------------------
#
# Processing data file: subj4_series5_data.csv
# Extracted subject: 4, series: 5
# Looking for events file: subj4_series5_events.csv
# Loading data from subj4_series5_data.csv
# Loaded data shape: (123027, 32)
# Loading events from subj4_series5_events.csv
# Loaded labels shape: (123027, 5)
# Added data to batch. Current total features shape: (17608602, 32), labels shape: (17608602, 5)
# --------------------------------------------------
#
# Processing data file: subj1_series8_data.csv
# Extracted subject: 1, series: 8
# Looking for events file: subj1_series8_events.csv
# Loading data from subj1_series8_data.csv
# Loaded data shape: (117333, 32)
# Loading events from subj1_series8_events.csv
# Loaded labels shape: (117333, 5)
# Added data to batch. Current total features shape: (17725935, 32), labels shape: (17725935, 5)
# --------------------------------------------------
#
# Processing data file: subj9_series6_data.csv
# Extracted subject: 9, series: 6
# Looking for events file: subj9_series6_events.csv
# Loading data from subj9_series6_data.csv
# Loaded data shape: (131609, 32)
# Loading events from subj9_series6_events.csv
# Loaded labels shape: (131609, 5)
# Added data to batch. Current total features shape: (17857544, 32), labels shape: (17857544, 5)
# --------------------------------------------------
#
# Processing data file: subj9_series7_data.csv
# Extracted subject: 9, series: 7
# Looking for events file: subj9_series7_events.csv
# Loading data from subj9_series7_data.csv
# Loaded data shape: (128210, 32)
# Loading events from subj9_series7_events.csv
# Loaded labels shape: (128210, 5)
# Added data to batch. Current total features shape: (17985754, 32), labels shape: (17985754, 5)
# --------------------------------------------------
#
# Combining all data into tensors...
# Final features tensor shape: torch.Size([17985754, 32])
# Final labels tensor shape: torch.Size([17985754, 5])
#
# Data loading completed successfully!
# Found 24 data files in the folder: grasp-and-lift-eeg-detection/test
#
# Processing data file: subj6_series9_data.csv
# Extracted subject: 6, series: 9
# Looking for events file: subj6_series9_events.csv
# Events file not found for subj6_series9_data.csv, skipping...
#
# Processing data file: subj10_series9_data.csv
# Extracted subject: 10, series: 9
# Looking for events file: subj10_series9_events.csv
# Events file not found for subj10_series9_data.csv, skipping...
#
# Processing data file: subj2_series9_data.csv
# Extracted subject: 2, series: 9
# Looking for events file: subj2_series9_events.csv
# Events file not found for subj2_series9_data.csv, skipping...
#
# Processing data file: subj9_series9_data.csv
# Extracted subject: 9, series: 9
# Looking for events file: subj9_series9_events.csv
# Events file not found for subj9_series9_data.csv, skipping...
#
# Processing data file: subj8_series10_data.csv
# Extracted subject: 8, series: 10
# Looking for events file: subj8_series10_events.csv
# Events file not found for subj8_series10_data.csv, skipping...
#
# Processing data file: subj7_series9_data.csv
# Extracted subject: 7, series: 9
# Looking for events file: subj7_series9_events.csv
# Events file not found for subj7_series9_data.csv, skipping...
#
# Processing data file: subj3_series9_data.csv
# Extracted subject: 3, series: 9
# Looking for events file: subj3_series9_events.csv
# Events file not found for subj3_series9_data.csv, skipping...
#
# Processing data file: subj11_series9_data.csv
# Extracted subject: 11, series: 9
# Looking for events file: subj11_series9_events.csv
# Events file not found for subj11_series9_data.csv, skipping...
#
# Processing data file: subj8_series9_data.csv
# Extracted subject: 8, series: 9
# Looking for events file: subj8_series9_events.csv
# Events file not found for subj8_series9_data.csv, skipping...
#
# Processing data file: subj9_series10_data.csv
# Extracted subject: 9, series: 10
# Looking for events file: subj9_series10_events.csv
# Events file not found for subj9_series10_data.csv, skipping...
#
# Processing data file: subj11_series10_data.csv
# Extracted subject: 11, series: 10
# Looking for events file: subj11_series10_events.csv
# Events file not found for subj11_series10_data.csv, skipping...
#
# Processing data file: subj4_series9_data.csv
# Extracted subject: 4, series: 9
# Looking for events file: subj4_series9_events.csv
# Events file not found for subj4_series9_data.csv, skipping...
#
# Processing data file: subj5_series10_data.csv
# Extracted subject: 5, series: 10
# Looking for events file: subj5_series10_events.csv
# Events file not found for subj5_series10_data.csv, skipping...
#
# Processing data file: subj1_series10_data.csv
# Extracted subject: 1, series: 10
# Looking for events file: subj1_series10_events.csv
# Events file not found for subj1_series10_data.csv, skipping...
#
# Processing data file: subj10_series10_data.csv
# Extracted subject: 10, series: 10
# Looking for events file: subj10_series10_events.csv
# Events file not found for subj10_series10_data.csv, skipping...
#
# Processing data file: subj4_series10_data.csv
# Extracted subject: 4, series: 10
# Looking for events file: subj4_series10_events.csv
# Events file not found for subj4_series10_data.csv, skipping...
#
# Processing data file: subj12_series9_data.csv
# Extracted subject: 12, series: 9
# Looking for events file: subj12_series9_events.csv
# Events file not found for subj12_series9_data.csv, skipping...
#
# Processing data file: subj2_series10_data.csv
# Extracted subject: 2, series: 10
# Looking for events file: subj2_series10_events.csv
# Events file not found for subj2_series10_data.csv, skipping...
#
# Processing data file: subj5_series9_data.csv
# Extracted subject: 5, series: 9
# Looking for events file: subj5_series9_events.csv
# Events file not found for subj5_series9_data.csv, skipping...
#
# Processing data file: subj7_series10_data.csv
# Extracted subject: 7, series: 10
# Looking for events file: subj7_series10_events.csv
# Events file not found for subj7_series10_data.csv, skipping...
#
# Processing data file: subj12_series10_data.csv
# Extracted subject: 12, series: 10
# Looking for events file: subj12_series10_events.csv
# Events file not found for subj12_series10_data.csv, skipping...
#
# Processing data file: subj3_series10_data.csv
# Extracted subject: 3, series: 10
# Looking for events file: subj3_series10_events.csv
# Events file not found for subj3_series10_data.csv, skipping...
#
# Processing data file: subj6_series10_data.csv
# Extracted subject: 6, series: 10
# Looking for events file: subj6_series10_events.csv
# Events file not found for subj6_series10_data.csv, skipping...
#
# Processing data file: subj1_series9_data.csv
# Extracted subject: 1, series: 9
# Looking for events file: subj1_series9_events.csv
# Events file not found for subj1_series9_data.csv, skipping...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 84
#      82     return features_tensor, labels_tensor
#      83 train_features, train_labels = load_eeg_dataset('grasp-and-lift-eeg-detection/train')
# ---> 84 test_features, test_labels = load_eeg_dataset('grasp-and-lift-eeg-detection/test')
#
# Cell In[1], line 72, in load_eeg_dataset(folder_path)
#      70 # Check if any valid data was found
#      71 if len(all_features) == 0 or len(all_labels) == 0:
# ---> 72     raise ValueError("No valid data files found in the specified folder.")
#      74 # Combine all data
#      75 print("\nCombining all data into tensors...")
#
# ValueError: No valid data files found in the specified folder.

# %%
# test_features, test_labels = load_eeg_dataset('grasp-and-lift-eeg-detection/test')

# %%
train_features.shape
# Out:
# torch.Size([17985754, 32])

# %%
train_labels.shape
# Out:
# torch.Size([17985754, 5])

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# Data Preprocessing
def preprocess_data(features, labels):
    """
    Normalize features and convert data to float tensors.
    """
    # Normalize features
    mean = features.mean(dim=0, keepdim=True)
    std = features.std(dim=0, keepdim=True) + 1e-6  # Avoid division by zero
    features = (features - mean) / std
    
    # Convert to float tensors
    return features.float(), labels.float()

train_features, train_labels = preprocess_data(train_features, train_labels)

# Define Dataset and DataLoader
batch_size = 128  # Adjust as needed for memory constraints
dataset = TensorDataset(train_features, train_labels)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Define Neural Network Model
class EEGNet(nn.Module):
    def __init__(self, input_dim=32, output_dim=5, hidden_dim=64):
        super(EEGNet, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, output_dim),
            nn.Sigmoid()  # Since it's multi-label classification
        )
    
    def forward(self, x):
        return self.model(x)

# Initialize Model, Loss, and Optimizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = EEGNet().to(device)
criterion = nn.BCELoss()  # Since outputs are between 0 and 1 (multi-label classification)
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
# Training Loop
epochs = 10  # Adjust as needed
for epoch in range(epochs):
    running_loss = 0.0
    for batch_idx, (inputs, targets) in enumerate(dataloader):
        inputs, targets = inputs.to(device), targets.to(device)
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        print(loss.item())
        
    print(f"Epoch [{epoch+1}/{epochs}], Loss: {running_loss/len(dataloader):.4f}")

print("Training Complete!")
# Out:
# 0.11059276014566422
# 0.10184314101934433
# 0.11308792978525162
# 0.0921778455376625
# 0.11653312295675278
# 0.11786184459924698
# 0.09854574501514435
# 0.11223316192626953
# 0.08460733294487
# 0.1577948033809662
# 0.08788762986660004
# 0.09244047105312347
# 0.0956498235464096
# 0.13062074780464172
# 0.10265807062387466
# 0.11953897774219513
# 0.11847994476556778
# 0.10766235738992691
# 0.08647976815700531
# 0.09948794543743134
# 0.11704540252685547
# 0.10211054980754852
